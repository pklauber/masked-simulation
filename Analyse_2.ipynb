# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#This is also doable with a List of Lists, but that reduces the code readability by A LOT so I decided to go with this less efficient but easier-to-understand approach. Its a py-Notebook after all.
#Mask-Protection = 10% and 30%
e1030_205 = pd.read_csv("Experiment_data/experiment2_10-30_20-5.csv")
e1030_2050 = pd.read_csv("Experiment_data/experiment2_10-30_20-50.csv")
e1030_5035 = pd.read_csv("Experiment_data/experiment2_10-30_50-35.csv")
e1030_705 = pd.read_csv("Experiment_data/experiment2_10-30_70-5.csv")

#Mask-Protection = 50% and 70%
e5070_205 = pd.read_csv("Experiment_data/experiment2_50-70_20-5.csv")
e5070_2050 = pd.read_csv("Experiment_data/experiment2_50-70_20-50.csv")
e5070_5035 = pd.read_csv("Experiment_data/experiment2_50-70_50-35.csv")
e5070_705 = pd.read_csv("Experiment_data/experiment2_50-70_70-5.csv")

#Mask-Protection = 20% and 45%
#Mask-Percentage 1 = 5%
e2045_55 = pd.read_csv("Experiment_data/experiment2_20-45_5-5.csv")
e2045_520 = pd.read_csv("Experiment_data/experiment2_20-45_5-20.csv")
e2045_535 = pd.read_csv("Experiment_data/experiment2_20-45_5-35.csv")
e2045_550 = pd.read_csv("Experiment_data/experiment2_20-45_5-50.csv")
e2045_570 = pd.read_csv("Experiment_data/experiment2_20-45_5-70.csv")

#Mask-Percentage 1 = 20%
e2045_205 = pd.read_csv("Experiment_data/experiment2_20-45_20-5.csv")
e2045_2020 = pd.read_csv("Experiment_data/experiment2_20-45_20-20.csv")
e2045_2035 = pd.read_csv("Experiment_data/experiment2_20-45_20-35.csv")
e2045_2050 = pd.read_csv("Experiment_data/experiment2_20-45_20-50.csv")
e2045_2070 = pd.read_csv("Experiment_data/experiment2_20-45_20-70.csv")

#Mask-Percentage 1 = 35%
e2045_355 = pd.read_csv("Experiment_data/experiment2_20-45_35-5.csv")
e2045_3520 = pd.read_csv("Experiment_data/experiment2_20-45_35-20.csv")
e2045_3535 = pd.read_csv("Experiment_data/experiment2_20-45_35-35.csv")
e2045_3550 = pd.read_csv("Experiment_data/experiment2_20-45_35-50.csv")
e2045_3570 = pd.read_csv("Experiment_data/experiment2_20-45_35-70.csv")

#Mask-Percentage 1 = 50%
e2045_505 = pd.read_csv("Experiment_data/experiment2_20-45_50-5.csv")
e2045_5020 = pd.read_csv("Experiment_data/experiment2_20-45_50-20.csv")
e2045_5035 = pd.read_csv("Experiment_data/experiment2_20-45_50-35.csv")
e2045_5050 = pd.read_csv("Experiment_data/experiment2_20-45_50-50.csv")
e2045_5070 = pd.read_csv("Experiment_data/experiment2_20-45_50-70.csv")

#Mask-Percentage 1 = 70%
e2045_705 = pd.read_csv("Experiment_data/experiment2_20-45_70-5.csv")
e2045_7020 = pd.read_csv("Experiment_data/experiment2_20-45_70-20.csv")
e2045_7035 = pd.read_csv("Experiment_data/experiment2_20-45_70-35.csv")
e2045_7050 = pd.read_csv("Experiment_data/experiment2_20-45_70-50.csv")
e2045_7070 = pd.read_csv("Experiment_data/experiment2_20-45_70-70.csv")

#Mask-Protection = 30% and 60%
#Mask-Percentage 1 = 5%
e3060_55 = pd.read_csv("Experiment_data/experiment2_30-60_5-5.csv")
e3060_520 = pd.read_csv("Experiment_data/experiment2_30-60_5-20.csv")
e3060_535 = pd.read_csv("Experiment_data/experiment2_30-60_5-35.csv")
e3060_550 = pd.read_csv("Experiment_data/experiment2_30-60_5-50.csv")
e3060_570 = pd.read_csv("Experiment_data/experiment2_30-60_5-70.csv")

#Mask-Percentage 1 = 20%
e3060_205 = pd.read_csv("Experiment_data/experiment2_30-60_20-5.csv")
e3060_2020 = pd.read_csv("Experiment_data/experiment2_30-60_20-20.csv")
e3060_2035 = pd.read_csv("Experiment_data/experiment2_30-60_20-35.csv")
e3060_2050 = pd.read_csv("Experiment_data/experiment2_30-60_20-50.csv")
e3060_2070 = pd.read_csv("Experiment_data/experiment2_30-60_20-70.csv")

#Mask-Percentage 1 = 35%
e3060_355 = pd.read_csv("Experiment_data/experiment2_30-60_35-5.csv")
e3060_3520 = pd.read_csv("Experiment_data/experiment2_30-60_35-20.csv")
e3060_3535 = pd.read_csv("Experiment_data/experiment2_30-60_35-35.csv")
e3060_3550 = pd.read_csv("Experiment_data/experiment2_30-60_35-50.csv")
e3060_3570 = pd.read_csv("Experiment_data/experiment2_30-60_35-70.csv")

#Mask-Percentage 1 = 50%
e3060_505 = pd.read_csv("Experiment_data/experiment2_30-60_50-5.csv")
e3060_5020 = pd.read_csv("Experiment_data/experiment2_30-60_50-20.csv")
e3060_5035 = pd.read_csv("Experiment_data/experiment2_30-60_50-35.csv")
e3060_5050 = pd.read_csv("Experiment_data/experiment2_30-60_50-50.csv")
e3060_5070 = pd.read_csv("Experiment_data/experiment2_30-60_50-70.csv")

#Mask-Percentage 1 = 70%
e3060_705 = pd.read_csv("Experiment_data/experiment2_30-60_70-5.csv")
e3060_7020 = pd.read_csv("Experiment_data/experiment2_30-60_70-20.csv")
e3060_7035 = pd.read_csv("Experiment_data/experiment2_30-60_70-35.csv")
e3060_7050 = pd.read_csv("Experiment_data/experiment2_30-60_70-50.csv")
e3060_7070 = pd.read_csv("Experiment_data/experiment2_30-60_70-70.csv")

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e1030_5035["infected turtles"], label = "10%, 30%")
plt.plot(e2045_5035["infected turtles"], label = "20%, 45%")
plt.plot(e3060_5035["infected turtles"], label = "30%, 60%")
plt.plot(e5070_5035["infected turtles"], label = "50%, 70%")

plt.title('Infected turtles over time with 50% Mask 1, 35% Mask 2 for all Mask protection values')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e2045_205["infected turtles"], label = "20%, 5%")
plt.plot(e2045_3520["infected turtles"], label = "35%, 20%")
plt.plot(e2045_7050["infected turtles"], label = "70%, 50%")

plt.title('different Mask Percentage for same Protection')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e2045_505["infected turtles"], label = "5%")
plt.plot(e2045_5020["infected turtles"], label = "20%")
plt.plot(e2045_5035["infected turtles"], label = "35%")
plt.plot(e2045_5050["infected turtles"], label = "50%")
plt.plot(e2045_5070["infected turtles"], label = "70%")

plt.title('Infected turtles over time for Mask Protections 20% and 45% and 50% wearing the weaker Mask')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e2045_2020["turtles"] - e2045_205["masked 1 turtles"] - e2045_205["masked 2 turtles"], label = "unmasked")
plt.plot(e2045_2020["masked 1 turtles"], label = "weaker Mask")
plt.plot(e2045_2020["masked 2 turtles"], label = "stronger Mask")


plt.title('Number of masked turtles for 20% wearing the weaker and 20% the stronger one compared to unmasked turtles')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e2045_7050["turtles"] - e2045_7050["masked 1 turtles"] - e2045_7050["masked 2 turtles"], label = "unmasked")
plt.plot(e2045_7050["masked 1 turtles"], label = "weaker Mask")
plt.plot(e2045_7050["masked 2 turtles"], label = "stronger Mask")


plt.title('Number of masked turtles for 70% wearing the weaker and 50% the stronger one compared to unmasked turtles')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e3060_7050["turtles"] - e3060_7050["masked 1 turtles"] - e3060_7050["masked 2 turtles"], label = "unmasked")
plt.plot(e3060_7050["masked 1 turtles"], label = "weaker Mask")
plt.plot(e3060_7050["masked 2 turtles"], label = "stronger Mask")


plt.title('Number of masked turtles for 70% wearing the weaker and 50% the stronger one compared to unmasked turtles with better mask protection')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e3060_3570["turtles"] - e3060_3570["masked 1 turtles"] - e3060_3570["masked 2 turtles"], label = "unmasked")
plt.plot(e3060_3570["masked 1 turtles"], label = "weaker Mask")
plt.plot(e3060_3570["masked 2 turtles"], label = "stronger Mask")


plt.title('Number of masked turtles for 50% wearing the weaker and 70% the stronger one compared to unmasked turtles with better mask protection')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(20,10)

plt.plot(e3060_705["infected turtles"], label = "70%, 5%")
plt.plot(e3060_570["infected turtles"], label = "5%, 70%")


plt.title('Comparison of switched Number of Mask wearing turtles per mask')

plt.xlabel("Time")
plt.ylabel("Number of turtles")

plt.legend()
plt.show()
